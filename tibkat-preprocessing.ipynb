# %%
# Import necessary libraries
import os
import pandas as pd
import json
from git import Repo

# Clone the GitHub repository
git_url = "https://github.com/jd-coderepos/llms4subjects.git"
repo_dir = "llms4subjects"

if not os.path.exists(repo_dir):
    print("Cloning repository...")
    Repo.clone_from(git_url, repo_dir)
else:
    print("Repository already cloned.")

# Path to the target folder
data_folders = ["Article", "Book", "Conference", "Report", "Thesis"]
#data_folder = os.path.join(repo_dir, "shared-task-datasets", "TIBKAT", "tib-core-subjects", "data", "train", "Book", "en")

# Verify the folder exists
#if not os.path.exists(data_folder):
#    raise FileNotFoundError(f"The folder {data_folder} does not exist.")
# Out:
# Cloning repository...

# %%
def get_raw_dict_book(book, file_name, folder):
  raw = {}
  data = {}
  label = {}
  for item in book["@graph"]:
    if "title" in item:
      data["file_name"] = file_name
      data["folder"] = folder
      data["title"] = item["title"]
      data["abstract"] = item["abstract"]
      if ("creator" in item):
        gnd_creator = []
        if (isinstance(item["creator"], list)):
          gnd_creator = item["creator"]
        else:
          gnd_creator = [item["creator"]]
        name_creator = []
        for gnd in gnd_creator:
          for finder in book["@graph"]:
            if "@id" in finder and finder["@id"] == gnd:
              name_creator.append(finder["sameAs"])
        data["creator"] = name_creator
      if ("publisher" in item):
        data["publisher"] = item["publisher"]
      if ("@id" in item["dcterms:subject"]):
        item["dcterms:subject"] = [item["dcterms:subject"]]
      label["dcterms:subject"] = [x["@id"] for x in item["dcterms:subject"]]
      dcterms_name = []
      for dcterms in label["dcterms:subject"]:
        for finder in book["@graph"]:
          if "@id" in finder and finder["@id"] == dcterms:
            dcterms_name.append(finder["sameAs"])
      label["dcterms:subject_name"] = dcterms_name
      raw.update(data)
      raw.update(label)
  return raw

# %%
# Iterate through all JSON-LD files in the folder
langs = ["de","en"]
core_all = ["tib-core-subjects","all-subjects"]
for lang in langs:
  all_data = []
  for fold in core_all:
    for folder in data_folders :
      data_folder = os.path.join(repo_dir, "shared-task-datasets", "TIBKAT", fold, "data", "dev", folder, lang)
      if not os.path.exists(data_folder):
        raise FileNotFoundError(f"The folder {data_folder} does not exist.")
      for i, file_name in enumerate(os.listdir(data_folder)):
          if file_name.endswith(".jsonld"):
              if (i % 100 == 0):
                print(f"Processing file {i}: {file_name}")
              file_path = os.path.join(data_folder, file_name)
              with open(file_path, "r", encoding="utf-8") as f:
                  try:
                      # Load JSON-LD data
                      json_data = json.load(f)
                      preprocessed_data = get_raw_dict_book(json_data, file_name, folder)
                      all_data.append(preprocessed_data)
                  except json.JSONDecodeError as e:
                      print(f"Error decoding {file_name}: {e}")
    dataframe = pd.DataFrame(all_data)
    output_file = f"tibkat_{lang}_{fold}_dev.csv"
    dataframe.to_csv(output_file, index=False)

    print(f"Data saved to {output_file}")
# Out:
# Processing file 0: 3A175995943X.jsonld
# Processing file 0: 3A169918481X.jsonld
# Processing file 100: 3A1603625615.jsonld
# Processing file 200: 3A1694017435.jsonld
# Processing file 300: 3A392148943.jsonld
# Processing file 400: 3A1645186733.jsonld
# Processing file 500: 3A1030104921.jsonld
# Processing file 600: 3A873723813.jsonld
# Processing file 700: 3A1738993361.jsonld
# Processing file 800: 3A1699136750.jsonld
# Processing file 900: 3A488024714.jsonld
# Processing file 1000: 3A1651691436.jsonld
# Processing file 1100: 3A1697216986.jsonld
# Processing file 1200: 3A1657537056.jsonld
# Processing file 1300: 3A1681727978.jsonld
# Processing file 1400: 3A1664587365.jsonld
# Processing file 1500: 3A1724726595.jsonld
# Processing file 1600: 3A1733467556.jsonld
# Processing file 1700: 3A1659469716.jsonld
# Processing file 1800: 3A278897452.jsonld
# Processing file 1900: 3A155361368.jsonld
# Processing file 2000: 3A1860643248.jsonld
# Processing file 0: 3A187616025X.jsonld
# Processing file 100: 3A160948360X.jsonld
# Processing file 0: 3A1015342671.jsonld
# Processing file 100: 3A472209507.jsonld
# Processing file 0: 3A523299591.jsonld
# Processing file 100: 3A877631522.jsonld
# Processing file 200: 3A515699985.jsonld
# Processing file 300: 3A1676091521.jsonld
# Processing file 400: 3A742425444.jsonld
# Processing file 500: 3A183784027X.jsonld
# Processing file 600: 3A1847937667.jsonld
# Data saved to tibkat_de_tib-core-subjects_dev.csv
# Processing file 0: 3A1762285517.jsonld
# Processing file 0: 3A736125191.jsonld
# Processing file 100: 3A656778768.jsonld
# Processing file 200: 3A1666003700.jsonld
# Processing file 300: 3A164613382X.jsonld
# Processing file 400: 3A1769715746.jsonld
# Processing file 500: 3A1678869058.jsonld
# Processing file 600: 3A1793501815.jsonld
# Processing file 700: 3A1675953503.jsonld
# Processing file 800: 3A390319317.jsonld
# Processing file 900: 3A68340413X.jsonld
# Processing file 1000: 3A588207977.jsonld
# Processing file 1100: 3A627258824.jsonld
# Processing file 1200: 3A1780780400.jsonld
# Processing file 1300: 3A785144781.jsonld
# Processing file 1400: 3A647523019.jsonld
# Processing file 1500: 3A1759335673.jsonld
# Processing file 1600: 3A1658667174.jsonld
# Processing file 1700: 3A1649084927.jsonld
# Processing file 1800: 3A503299960.jsonld
# Processing file 1900: 3A1648539890.jsonld
# Processing file 2000: 3A1607139243.jsonld
# Processing file 2100: 3A248823604.jsonld
# Processing file 2200: 3A1656799677.jsonld
# Processing file 2300: 3A1827840986.jsonld
# Processing file 2400: 3A250469391.jsonld
# Processing file 2500: 3A1725148749.jsonld
# Processing file 2600: 3A165090438X.jsonld
# Processing file 2700: 3A1854030221.jsonld
# Processing file 2800: 3A1603861173.jsonld
# Processing file 2900: 3A1008883786.jsonld
# Processing file 3000: 3A1609335694.jsonld
# Processing file 3100: 3A232102627.jsonld
# Processing file 3200: 3A510446329.jsonld
# Processing file 3300: 3A188341685X.jsonld
# Processing file 3400: 3A510039634.jsonld
# Processing file 3500: 3A74716066X.jsonld
# Processing file 3600: 3A153304766.jsonld
# Processing file 3700: 3A1784889636.jsonld
# Processing file 3800: 3A024788058.jsonld
# Processing file 3900: 3A1655901192.jsonld
# Processing file 4000: 3A1650561776.jsonld
# Processing file 4100: 3A489041418.jsonld
# Processing file 4200: 3A1653611669.jsonld
# Processing file 4300: 3A1871251842.jsonld
# Processing file 4400: 3A1650144334.jsonld
# Processing file 4500: 3A1041329504.jsonld
# Processing file 4600: 3A1656139197.jsonld
# Processing file 4700: 3A379099411.jsonld
# Processing file 4800: 3A644789093.jsonld
# Processing file 4900: 3A276265238.jsonld
# Processing file 5000: 3A731918460.jsonld
# Processing file 5100: 3A757304931.jsonld
# Processing file 5200: 3A1801275378.jsonld
# Processing file 5300: 3A555664260.jsonld
# Processing file 5400: 3A1769714537.jsonld
# Processing file 5500: 3A1885829825.jsonld
# Processing file 0: 3A372566359.jsonld
# Processing file 100: 3A1778414524.jsonld
# Processing file 200: 3A240099559.jsonld
# Processing file 300: 3A184042550.jsonld
# Processing file 0: 3A16408973X.jsonld
# Processing file 100: 3A389988782.jsonld
# Processing file 200: 3A387248706.jsonld
# Processing file 0: 3A100890757X.jsonld
# Processing file 100: 3A790244128.jsonld
# Processing file 200: 3A846130157.jsonld
# Processing file 300: 3A1655773224.jsonld
# Processing file 400: 3A1798059630.jsonld
# Processing file 500: 3A1788624718.jsonld
# Processing file 600: 3A509763588.jsonld
# Processing file 700: 3A1647277817.jsonld
# Processing file 800: 3A826170498.jsonld
# Processing file 900: 3A626477131.jsonld
# Processing file 1000: 3A1681808404.jsonld
# Processing file 1100: 3A547373317.jsonld
# Processing file 1200: 3A1694138666.jsonld
# Processing file 1300: 3A1653239638.jsonld
# Processing file 1400: 3A1827845988.jsonld
# Data saved to tibkat_de_all-subjects_dev.csv
# Processing file 0: 3A770763677.jsonld
# Processing file 0: 3A659268531.jsonld
# Processing file 100: 3A1743843992.jsonld
# Processing file 200: 3A87867067X.jsonld
# Processing file 300: 3A165526706X.jsonld
# Processing file 400: 3A1655424130.jsonld
# Processing file 500: 3A1800413785.jsonld
# Processing file 600: 3A1025562739.jsonld
# Processing file 700: 3A1725809133.jsonld
# Processing file 800: 3A628532318.jsonld
# Processing file 900: 3A1659031621.jsonld
# Processing file 1000: 3A684072920.jsonld
# Processing file 1100: 3A1703803299.jsonld
# Processing file 1200: 3A1700706349.jsonld
# Processing file 1300: 3A721181015.jsonld
# Processing file 1400: 3A1650780125.jsonld
# Processing file 1500: 3A1655565095.jsonld
# Processing file 1600: 3A1655972367.jsonld
# Processing file 1700: 3A1655391240.jsonld
# Processing file 1800: 3A715070878.jsonld
# Processing file 1900: 3A897753747.jsonld
# Processing file 2000: 3A1032126922.jsonld
# Processing file 2100: 3A686524322.jsonld
# Processing file 2200: 3A63135476X.jsonld
# Processing file 2300: 3A1693561697.jsonld
# Processing file 2400: 3A1677214244.jsonld
# Processing file 2500: 3A88930159X.jsonld
# Processing file 2600: 3A1744461236.jsonld
# Processing file 2700: 3A725763779.jsonld
# Processing file 2800: 3A1066747768.jsonld
# Processing file 2900: 3A1811739342.jsonld
# Processing file 0: 3A1655264931.jsonld
# Processing file 100: 3A1646686608.jsonld
# Processing file 200: 3A1655219367.jsonld
# Processing file 300: 3A744945984.jsonld
# Processing file 400: 3A826559581.jsonld
# Processing file 0: 3A461913720.jsonld
# Processing file 100: 3A538914939.jsonld
# Processing file 0: 3A884571696.jsonld
# Processing file 100: 3A507277988.jsonld
# Processing file 200: 3A1658934342.jsonld
# Processing file 300: 3A64075094X.jsonld
# Processing file 400: 3A1657025942.jsonld
# Data saved to tibkat_en_tib-core-subjects_dev.csv
# Processing file 0: 3A1831639777.jsonld
# Processing file 100: 3A1831641941.jsonld
# Processing file 0: 3A565192132.jsonld
# Processing file 100: 3A866005927.jsonld
# Processing file 200: 3A1789938732.jsonld
# Processing file 300: 3A749870125.jsonld
# Processing file 400: 3A1655499130.jsonld
# Processing file 500: 3A1742197035.jsonld
# Processing file 600: 3A1655657151.jsonld
# Processing file 700: 3A1605396915.jsonld
# Processing file 800: 3A683309056.jsonld
# Processing file 900: 3A016342534.jsonld
# Processing file 1000: 3A664559859.jsonld
# Processing file 1100: 3A524933812.jsonld
# Processing file 1200: 3A1647322030.jsonld
# Processing file 1300: 3A883311216.jsonld
# Processing file 1400: 3A1619660628.jsonld
# Processing file 1500: 3A1614184488.jsonld
# Processing file 1600: 3A64297893X.jsonld
# Processing file 1700: 3A1646598652.jsonld
# Processing file 1800: 3A1651934509.jsonld
# Processing file 1900: 3A1823841791.jsonld
# Processing file 2000: 3A721181031.jsonld
# Processing file 2100: 3A682277398.jsonld
# Processing file 2200: 3A1858356954.jsonld
# Processing file 2300: 3A89287404X.jsonld
# Processing file 2400: 3A376119802.jsonld
# Processing file 2500: 3A1651549540.jsonld
# Processing file 2600: 3A833119354.jsonld
# Processing file 2700: 3A1736821458.jsonld
# Processing file 2800: 3A1067716750.jsonld
# Processing file 2900: 3A882151223.jsonld
# Processing file 3000: 3A661725502.jsonld
# Processing file 3100: 3A1653537671.jsonld
# Processing file 3200: 3A102679658X.jsonld
# Processing file 3300: 3A1654283339.jsonld
# Processing file 3400: 3A884710335.jsonld
# Processing file 3500: 3A1650536496.jsonld
# Processing file 3600: 3A186608805X.jsonld
# Processing file 3700: 3A749134496.jsonld
# Processing file 3800: 3A1651727465.jsonld
# Processing file 3900: 3A1023437376.jsonld
# Processing file 4000: 3A1650745575.jsonld
# Processing file 4100: 3A1747883379.jsonld
# Processing file 4200: 3A1655878654.jsonld
# Processing file 4300: 3A160447758X.jsonld
# Processing file 4400: 3A626003032.jsonld
# Processing file 0: 3A689647115.jsonld
# Processing file 100: 3A880837616.jsonld
# Processing file 200: 3A1649261381.jsonld
# Processing file 300: 3A1608857689.jsonld
# Processing file 400: 3A188933877X.jsonld
# Processing file 500: 3A1012213730.jsonld
# Processing file 600: 3A717227316.jsonld
# Processing file 0: 3A387963111.jsonld
# Processing file 100: 3A521597773.jsonld
# Processing file 200: 3A1604857307.jsonld
# Processing file 0: 3A815369484.jsonld
# Processing file 100: 3A1025692632.jsonld
# Processing file 200: 3A1669233790.jsonld
# Processing file 300: 3A1025174224.jsonld
# Processing file 400: 3A1015244971.jsonld
# Processing file 500: 3A1668026619.jsonld
# Data saved to tibkat_en_all-subjects_dev.csv

# %%
dataframe = pd.DataFrame(all_data)

# %%
output_file = "tibkat_de_core_train.csv"
dataframe.to_csv(output_file, index=False)

print(f"Data saved to {output_file}")
# Out:
# Data saved to tibkat_de_core_train.csv
